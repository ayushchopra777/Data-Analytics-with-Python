# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushchopra777/Data-Analytics-with-Python/blob/main/DA_Lect_1_Ex_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a dictionary to store college information
college = {
    "name": "ABC Institute",   # College name

    # List of departments
    "departments": [
        {"name": "CSE", "students": 120},  # First department
        {"name": "ECE", "students": 90}    # Second department
    ]
}

# Print the name of the first department
print(college["departments"][0]["name"])
# Out:
# CSE
